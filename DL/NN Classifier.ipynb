# %% [markdown]
# # Universal imports

# %%
from google.colab import drive

# %%
import pandas as pd

# %%
# Import BERT-ready data from Gdrive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # other git stuff

# %%
# !git pull
# Out:
# remote: Enumerating objects: 2049, done.
# remote: Counting objects: 100% (2049/2049), done.
# remote: Compressing objects: 100% (1545/1545), done.
# remote: Total 2049 (delta 444), reused 2039 (delta 437), pack-reused 0
# Receiving objects: 100% (2049/2049), 3.22 MiB | 6.04 MiB/s, done.
# Resolving deltas: 100% (444/444), completed with 19 local objects.
# From https://github.com/TechLabs-Berlin/ss23-drop-in-to-berlin
#    7d03bb1..2e822c6  Recommender_API -> origin/Recommender_API
#  * [new branch]      backend         -> origin/backend
#    67e0a88..583f05c  main            -> origin/main
#  * [new branch]      review-and-price-range-restcard -> origin/review-and-price-range-restcard
# Updating 7d03bb1..2e822c6
# Fast-forward
#  API/templates/index.html                    |  41 --------------------------
#  {API => DL/API}/NearestNeighbors_clf.joblib | Bin
#  {API => DL/API}/flask_app.py                |  18 ++++++------
#  DL/API/requirements.txt                     | Bin 0 -> 2434 bytes
#  DL/API/templates/index.html                 |  20 +++++++++++++
#  {API => DL/API}/test.py                     |   0
#  DL/index_backu.html                         |  44 ++++++++++++++++++++++++++++
#  7 files changed, 73 insertions(+), 50 deletions(-)
#  delete mode 100644 API/templates/index.html
#  rename {API => DL/API}/NearestNeighbors_clf.joblib (100%)
#  rename {API => DL/API}/flask_app.py (71%)
#  create mode 100644 DL/API/requirements.txt
#  create mode 100644 DL/API/templates/index.html
#  rename {API => DL/API}/test.py (100%)
#  create mode 100644 DL/index_backu.html

# %%
cd /content/gdrive/MyDrive/TechLabs/{repository}
# Out:
# /content/gdrive/MyDrive/TechLabs/ss23-drop-in-to-berlin

# %%
# !git branch -a
# Out:
# * KNN_classifier
#   main
#   recommender
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/KNN_classifier
#   remotes/origin/Leo_local_pycharm
#   remotes/origin/Recommender_API
#   remotes/origin/main
#   remotes/origin/new-scraped-data
#   remotes/origin/recommender
#   remotes/origin/script-and-SearchResultsPage
#   remotes/origin/star-rating-change
#   remotes/origin/star-rating-fix

# %%
# !git fetch --all
# Out:
# Fetching origin

# %%
# !git checkout Recommender_API
# Out:
# Updating files: 100% (6/6), done.
# Branch 'Recommender_API' set up to track remote branch 'Recommender_API' from 'origin'.
# Switched to a new branch 'Recommender_API'

# %%
# !git remote set-url origin https://{git_token}@github.com/{username}/{repository}

# %%
# !git config --global user.email "phylanx@gmx.de"
# !git config --global user.name "phylanxy"

# %%
# !git add .

# %%
# !git commit -m "just commiting to be able to checkout"
# Out:
# [KNN_classifier dc7c953] just commiting to be able to checkout
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite DL/NN Classifier.ipynb (85%)

# %%
username = "TechLabs-Berlin"
repository = "ss23-drop-in-to-berlin"
git_token = ""

# %%
# !git status
# Out:
# On branch Recommender_API
# Your branch is up to date with 'origin/Recommender_API'.
#
# nothing to commit, working tree clean

# %% [markdown]
# # Loading the data & data cleaning

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Ironhack/Final_project/df_with_model_input_no_NaNs.csv")

# %%
# function to remove items specified in a list
def preprocess_input(string, lst_to_remove):
  for item in lst_to_remove:
    string = string.replace(item, "")
  if len(string.split()) < 4:
    string = None
  else:
    pass
  return string

# create a list to remove strings that don't carry meaning
remove_lst = ["'review0': ","'review1': ","'review2': ","'review3': ","'review4': ", "'editorial_summary':"]

# %%
# drop old indeces
df.drop(["Unnamed: 0", "Unnamed: 0.1"], inplace=True, axis=1)

# %%
# turn model input into the review text without the items specified in remove_lst
df["model_input"] = df["model_input"].apply(lambda x: preprocess_input(str(x), remove_lst) if x != None else "")

# %%
# drop NaNs from model_input col, otherwise embedding won't work later on
df.dropna(subset="model_input", inplace=True)

# %%
# convert everything into str, add empty string for anything that's not a string (keyBERT won't accept NaNs as input, but I want to preserve the order of the inputs, for correct assignemetn of the outputs to the corresponding rows)
# and then create a list of texts for keyBERT to process
BERTs = df["model_input"]

# %%
# save edited database to .csv
df.to_csv("database_Leo.csv", index_label=False)

# %%
df = pd.read_csv("database_Leo.csv")

# %%
df
# Out:
#       Unnamed: 0.2                                               name  \
# 0                0                            Restaurant „Zur S-Bahn“
# 1                1                           Restaurant am Steinplatz
# 2                2                                   Restaurant Nolle
# 3                3                                  Restaurant Daheim
# 4                4  Lahn-Eck Berlin Das gemütliche Schank und Spei...
# ...            ...                                                ...
# 4297          4297                                         Vino Greco
# 4298          4298                              Asia Restaurant Sonne
# 4299          4299                                   Grand Bar Berlin
# 4300          4300                                  Cantina Siciliana
# 4301          4301                                     Namaste Italia
#
#                         reference  \
# 0     ChIJAergcnhJqEcRST9W0VduzeY
# 1     ChIJaw12ev1QqEcRUApn-mBv2vM
# 2     ChIJWc98GMNRqEcRJKn-jkqXZgA
# 3     ChIJgTRA3fdNqEcRplfCByWlpO8
# 4     ChIJ80Ss-Z1PqEcRpsXmnT9JdUc
# ...                           ...
# 4297  ChIJqfomdtlQqEcRDbh3R4hqQiY
# 4298  ChIJe_aa4NNQqEcRvGVumhyxim4
# 4299  ChIJtdceUytXqEcRBvUYLcJKo2M
# 4300  ChIJr0qHXtZQqEcRI8A-t0OCzg8
# 4301  ChIJE_9BYY9PqEcRF41eUi4CZrs
#
#                                                geometry  \
# 0     {'location': {'lat': 52.5125038, 'lng': 13.587...
# 1     {'location': {'lat': 52.50790970000001, 'lng':...
# 2     {'location': {'lat': 52.51996279999999, 'lng':...
# 3     {'location': {'lat': 52.5531136, 'lng': 13.423...
# 4     {'location': {'lat': 52.46764289999999, 'lng':...
# ...                                                 ...
# 4297  {'location': {'lat': 52.5115677, 'lng': 13.269...
# 4298  {'location': {'lat': 52.50666289999999, 'lng':...
# 4299  {'location': {'lat': 52.5094664, 'lng': 13.277...
# 4300  {'location': {'lat': 52.5106518, 'lng': 13.288...
# 4301  {'location': {'lat': 52.4626828, 'lng': 13.380...
#
#                                       formatted_address  price_level  rating  \
# 0       Heinrich-Grüber-Straße 1, 12621 Berlin, Germany          2.0     4.6
# 1                     Steinpl. 4, 10623 Berlin, Germany          NaN     4.4
# 2     S-Bahnbogen 203, Georgenstraße 203, 10117 Berl...          2.0     4.3
# 3              Neumannstraße 136, 13189 Berlin, Germany          2.0     4.4
# 4           Karl-Marx-Straße 241, 12057 Berlin, Germany          1.0     4.4
# ...                                                 ...          ...     ...
# 4297              Reichsstraße 5, 14052 Berlin, Germany          2.0     4.7
# 4298          Neue Kantstraße 16, 14057 Berlin, Germany          2.0     3.9
# 4299               Kaiserdamm 80, 14057 Berlin, Germany          NaN     4.2
# 4300               Kaiserdamm 15, 14057 Berlin, Germany          NaN     4.5
# 4301                Bosestraße 6, 12103 Berlin, Germany          NaN     4.8
#
#       user_ratings_total                                              types  \
# 0                 1551.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 1                   79.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 2                 2026.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 3                  758.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 4                  147.0  ['restaurant', 'food', 'point_of_interest', 'e...
# ...                  ...                                                ...
# 4297               131.0  ['liquor_store', 'store', 'restaurant', 'food'...
# 4298               602.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 4299                53.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 4300               222.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 4301               174.0  ['restaurant', 'food', 'point_of_interest', 'e...
#
#                                       editorial_summary  ...  \
# 0     {'language': 'en', 'overview': 'Pork knuckles,...  ...
# 1     {'language': 'en', 'overview': 'Sophisticated ...  ...
# 2     {'language': 'en', 'overview': 'Homestyle dish...  ...
# 3     {'language': 'en', 'overview': 'Relaxed establ...  ...
# 4     {'language': 'en', 'overview': 'Generous porti...  ...
# ...                                                 ...  ...
# 4297                                                NaN  ...
# 4298  {'language': 'en', 'overview': 'Long-standing ...  ...
# 4299                                                NaN  ...
# 4300                                                NaN  ...
# 4301  {'language': 'en', 'overview': 'Mellow restaur...  ...
#
#      wheelchair_accessible_entrance  \
# 0                               0.0
# 1                               1.0
# 2                               1.0
# 3                               0.0
# 4                               NaN
# ...                             ...
# 4297                            1.0
# 4298                            1.0
# 4299                            NaN
# 4300                            NaN
# 4301                            1.0
#
#                                                 website  \
# 0                             http://www.zur-s-bahn.de/
# 1                  http://www.restaurantsteinplatz.com/
# 2                       http://www.restaurant-nolle.de/
# 3                      http://www.willkommen-daheim.de/
# 4     https://shica.pw/lahn-eck-berlin-das-gemutlich...
# ...                                                 ...
# 4297                         http://www.vino-greco.com/
# 4298              https://asia-restaurant-sonne.berlin/
# 4299                                                NaN
# 4300                    http://www.cantinasiciliana.de/
# 4301  https://namasteitalia.business.site/?utm_sourc...
#
#       international_phone_number  \
# 0                 +49 30 5627003
# 1             +49 30 55444407053
# 2                 +49 30 2082645
# 3                +49 30 68917502
# 4                 +49 30 6851001
# ...                          ...
# 4297             +49 30 31518484
# 4298             +49 30 20889588
# 4299                         NaN
# 4300              +49 30 3228455
# 4301              +49 30 7517603
#
#                                                  photos  \
# 0     [{'height': 3584, 'html_attributions': ['<a hr...
# 1     [{'height': 1080, 'html_attributions': ['<a hr...
# 2     [{'height': 3744, 'html_attributions': ['<a hr...
# 3     [{'height': 669, 'html_attributions': ['<a hre...
# 4     [{'height': 3024, 'html_attributions': ['<a hr...
# ...                                                 ...
# 4297  [{'height': 1224, 'html_attributions': ['<a hr...
# 4298  [{'height': 2448, 'html_attributions': ['<a hr...
# 4299  [{'height': 1920, 'html_attributions': ['<a hr...
# 4300  [{'height': 3024, 'html_attributions': ['<a hr...
# 4301  [{'height': 2269, 'html_attributions': ['<a hr...
#
#                                         vicinity  \
# 0               Heinrich-Grüber-Straße 1, Berlin
# 1                             Steinpl. 4, Berlin
# 2     S-Bahnbogen 203, Georgenstraße 203, Berlin
# 3                      Neumannstraße 136, Berlin
# 4                   Karl-Marx-Straße 241, Berlin
# ...                                          ...
# 4297                      Reichsstraße 5, Berlin
# 4298                  Neue Kantstraße 16, Berlin
# 4299                       Kaiserdamm 80, Berlin
# 4300                       Kaiserdamm 15, Berlin
# 4301                        Bosestraße 6, Berlin
#
#                                                     url  business_status  \
# 0     https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 1     https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 2     https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 3     https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 4     https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# ...                                                 ...              ...
# 4297  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 4298  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 4299  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 4300  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 4301  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
#
#       permanently_closed                                          plus_code  \
# 0                    NaN  {'compound_code': 'GH6Q+X4 Berlin', 'global_co...
# 1                    NaN  {'compound_code': 'G85G+5G Berlin', 'global_co...
# 2                    NaN  {'compound_code': 'G99Q+XM Berlin', 'global_co...
# 3                    NaN  {'compound_code': 'HC3F+6G Berlin', 'global_co...
# 4                    NaN  {'compound_code': 'FC9R+3V Berlin', 'global_co...
# ...                  ...                                                ...
# 4297                 NaN  {'compound_code': 'G769+JV Berlin', 'global_co...
# 4298                 NaN  {'compound_code': 'G74M+MP Berlin', 'global_co...
# 4299                 NaN  {'compound_code': 'G75H+Q3 Berlin', 'global_co...
# 4300                 NaN  {'compound_code': 'G76Q+76 Berlin', 'global_co...
# 4301                 NaN  {'compound_code': 'F97J+35 Berlin', 'global_co...
#
#                                             model_input
# 0     'authentic german cuisine, friendly & fast ser...
# 1     'this must be one of the best kept culinary se...
# 2     'lovely authentic germany restaurant in a beau...
# 3     "my german friend took me here for an early ch...
# 4     "have a taste of germany in berlin. german bee...
# ...                                                 ...
# 4297  'its a must go restaurant. in case you in mood...
# 4298  'very authentic chinese restaurant, friendly s...
# 4299  'food taste is good for indian visitor', 'good...
# 4300  "delicious food, kind service, a must stop for...
# 4301  'our favourite indian cafe in berlin! always s...
#
# [4273 rows x 33 columns]

# %% [markdown]
# # use KNN on embeddings directly

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0 (from sentence_transformers)
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Collecting sentencepiece (from sentence_transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.9 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence_transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.6 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=ad78fb2eeb1e7ef3a3001bfbb752e01637d4fe27d344679cb6160aad1aaf3b48
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# Installing collected packages: tokenizers, sentencepiece, safetensors, huggingface-hub, transformers, sentence_transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.3.3 sentence_transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.33.2

# %%
from sentence_transformers import SentenceTransformer
import pickle

# %%
# build sentence embeddings based on all-MiniLM-L6-v2
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
model.max_seq_length = 512 # Change the length to 512

# %%
# save SentenceTransformer model to a .joblib file to be able to omit importing
# the corresponding library on python anywhere
from joblib import dump, load
dump(model, 'SentenceTransformer_model_py3.8.joblib')
# Out:
# ['SentenceTransformer_model_py3.8.joblib']

# %%
# get embeddings for all restaurant reviews (concatenated into 5 reviews per restaurant)
embeddings = model.encode(df["model_input"].to_numpy())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # get embeddings for all restaurant reviews (concatenated into 5 reviews per restaurant)
# ----> 2 embeddings = model.encode(df["model_input"].to_numpy())
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\sentence_transformers\SentenceTransformer.py:165, in SentenceTransformer.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     162 features = batch_to_device(features, device)
#     164 with torch.no_grad():
# --> 165     out_features = self.forward(features)
#     167     if output_value == 'token_embeddings':
#     168         embeddings = []
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\sentence_transformers\models\Transformer.py:66, in Transformer.forward(self, features)
#      63 if 'token_type_ids' in features:
#      64     trans_features['token_type_ids'] = features['token_type_ids']
# ---> 66 output_states = self.auto_model(**trans_features, return_dict=False)
#      67 output_tokens = output_states[0]
#      69 features.update({'token_embeddings': output_tokens, 'attention_mask': features['attention_mask']})
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\transformers\models\bert\modeling_bert.py:1020, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1011 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1013 embedding_output = self.embeddings(
#    1014     input_ids=input_ids,
#    1015     position_ids=position_ids,
#    (...)
#    1018     past_key_values_length=past_key_values_length,
#    1019 )
# -> 1020 encoder_outputs = self.encoder(
#    1021     embedding_output,
#    1022     attention_mask=extended_attention_mask,
#    1023     head_mask=head_mask,
#    1024     encoder_hidden_states=encoder_hidden_states,
#    1025     encoder_attention_mask=encoder_extended_attention_mask,
#    1026     past_key_values=past_key_values,
#    1027     use_cache=use_cache,
#    1028     output_attentions=output_attentions,
#    1029     output_hidden_states=output_hidden_states,
#    1030     return_dict=return_dict,
#    1031 )
#    1032 sequence_output = encoder_outputs[0]
#    1033 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\transformers\models\bert\modeling_bert.py:610, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     601     layer_outputs = torch.utils.checkpoint.checkpoint(
#     602         create_custom_forward(layer_module),
#     603         hidden_states,
#    (...)
#     607         encoder_attention_mask,
#     608     )
#     609 else:
# --> 610     layer_outputs = layer_module(
#     611         hidden_states,
#     612         attention_mask,
#     613         layer_head_mask,
#     614         encoder_hidden_states,
#     615         encoder_attention_mask,
#     616         past_key_value,
#     617         output_attentions,
#     618     )
#     620 hidden_states = layer_outputs[0]
#     621 if use_cache:
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\transformers\models\bert\modeling_bert.py:495, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     483 def forward(
#     484     self,
#     485     hidden_states: torch.Tensor,
#    (...)
#     492 ) -> Tuple[torch.Tensor]:
#     493     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     494     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 495     self_attention_outputs = self.attention(
#     496         hidden_states,
#     497         attention_mask,
#     498         head_mask,
#     499         output_attentions=output_attentions,
#     500         past_key_value=self_attn_past_key_value,
#     501     )
#     502     attention_output = self_attention_outputs[0]
#     504     # if decoder, the last output is tuple of self-attn cache
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\transformers\models\bert\modeling_bert.py:425, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     415 def forward(
#     416     self,
#     417     hidden_states: torch.Tensor,
#    (...)
#     423     output_attentions: Optional[bool] = False,
#     424 ) -> Tuple[torch.Tensor]:
# --> 425     self_outputs = self.self(
#     426         hidden_states,
#     427         attention_mask,
#     428         head_mask,
#     429         encoder_hidden_states,
#     430         encoder_attention_mask,
#     431         past_key_value,
#     432         output_attentions,
#     433     )
#     434     attention_output = self.output(self_outputs[0], hidden_states)
#     435     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\berlinbitesPython3_8\lib\site-packages\transformers\models\bert\modeling_bert.py:353, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     350     attention_scores = attention_scores + attention_mask
#     352 # Normalize the attention scores to probabilities.
# --> 353 attention_probs = nn.functional.softmax(attention_scores, dim=-1)
#     355 # This is actually dropping out entire tokens to attend to, which might
#     356 # seem a bit unusual, but is taken from the original Transformer paper.
#     357 attention_probs = self.dropout(attention_probs)
#
# KeyboardInterrupt:

# %%
#Store reviews & embeddings on disc
with open('embeddings.pkl', "wb") as fOut:
    pickle.dump({'sentences': df["model_input"].to_numpy(), 'embeddings': embeddings}, fOut, protocol=pickle.HIGHEST_PROTOCOL)

# %%
stored_embeddings.shape
# Out:
# (4273, 384)

# %%
# import stuff for NN algorithm
from sklearn.neighbors import NearestNeighbors
import numpy as np

# %%
# create a user input test
user_input = "Nestled discreetly in Berlin, this restaurant offers a harmonious fusion of classic and contemporary German flavors. The cozy, softly lit ambiance creates a warm welcome. I savored a velvety Kartoffelsuppe followed by a tender Schweinshaxe. Attentive staff provided impeccable wine pairings. It's an unforgettable culinary gem worth seeking out."
#"This is really one of the most delicious vietnamnese restaurants I've ever seen. It tastes exacly like when my mom used to cook. Especially the Pho was incredible. Would always come back"
user_embedding = model.encode(user_input).reshape(1,-1)

# %%
user_embedding.shape
# Out:
# (1, 384)

# %%
# build NearestNeighbors model that finds the
# 20 nearest restaurants to the user input
nbrs = NearestNeighbors(n_neighbors=20, algorithm='ball_tree').fit(stored_embeddings)

# %%
# save NN model to google drive
from joblib import dump, load
dump(nbrs, 'NearestNeighbors_clf_py3.8.joblib')
# Out:
# ['NearestNeighbors_clf_py3.8.joblib']

# %%
# save model to a pickle file instead
import pickle
with open("NearestNeighbors_clf.pkl", "wb") as f:
    pickle.dump(nbrs, f)

# %%
# predict closest neighbors
distances, indices = nbrs.kneighbors(user_embedding)
# Out:
# array([[ 277, 1275, 3648,  532, 2768, 1520, 1330, 2917,   29, 4075,  271,
#         1047,  646, 4084, 1167, 1048, 3425, 3045, 4256, 1417]])

# %%
# flatten array to use as index in dataframe
indices = indices.flatten()

# %%
# retrieve IDs of the restaurants to be sent to the app
df.iloc[indices]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-d6fbdbe657fd> in <cell line: 2>()
#       1 # retrieve IDs of the restaurants to be sent to the app
# ----> 2 df.iloc[indices]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## implement UMAP reducer to decrease dimensionality
# ## (this is not working -- aborting the experiment)

# %%
# !pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.2)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (67.7.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)

# %%
# define partial test vector for the embeddings
embs_test = embeddings[:100]

# fit and transform data using UMAP
reducer = umap.UMAP(n_components=10) # define reducer
umap_embs = reducer.fit_transform(embs_test) # return lower dimensionality vector

# %%
# create a user input test
user_input = "This is really one of the most delicious vietnamnese restaurants I've ever seen. It tastes exacly like when my mom used to cook. Especially the Pho was incredible. Would always come back"
user_embedding = model.encode(user_input).reshape(1,-1)
user_embs_umap = reducer.fit_transform(user_embedding)

# %%
umap_embs.shape, user_embs_umap.shape
# Out:
# ((100, 10), (1, 10))

# %%
embs_test.shape
# Out:
# (100, 384)

# %%
# build NearestNeighbors model that finds the 20 nearest restaurants to the user input
nbrs = NearestNeighbors(n_neighbors=20, algorithm='ball_tree').fit(umap_embs)
distances, indices = nbrs.kneighbors(user_embs_umap)

# %%
distances, indices
# Out:
# (array([[17.99023126, 18.00834927, 18.01500212, 18.09331552, 18.14265953,
#          18.16667835, 18.16842586, 18.19266265, 18.19817152, 18.25194706,
#          18.25717969, 18.26244017, 18.27342963, 18.29504493, 18.29722028,
#          18.30400719, 18.32640679, 18.48377698, 18.51090626, 18.53478569]]),
#  array([[57, 36, 88, 78, 79, 73, 65, 45, 75, 86, 54, 31, 26, 62, 13, 93,
#          66, 21, 49, 33]]))

# %%
df.iloc[indices.flatten()]
# Out:
#     Unnamed: 0.2                                               name  \
# 57            57                    CaliBocca Restaurant & Wine Bar
# 36            36                               Ristorante Portofino
# 88            88                             Standard Serious Pizza
# 78            78                                           Da Piada
# 79            79                                       Vino e libri
# 73            73                             Restaurant Via Nova II
# 65            65                                           Da Vinci
# 45            45                            Tiamo Restaurant berlin
# 75            75                                    Viale dei Tigli
# 86            86                                         Alimentari
# 54            54                                        Sale e Pepe
# 31            31                     Restaurant Trattoria Portofino
# 26            26                          EIN BESONDERES RESTAURANT
# 62            62                                            Dolcini
# 13            13  Restaurant Machiavelli - Italienisches & Alpen...
# 93            93                                             Donath
# 66            66                                     Bocca di Bacco
# 21            21                                 Restaurant Auszeit
# 49            49                                   Asteria Köpenick
# 33            33                                           Bellucci
#
#                       reference  \
# 57  ChIJ1Vrbe-RQqEcRnpasKjzVzTY
# 36  ChIJJZExZt5QqEcReiy8E2SmySc
# 88  ChIJB_FI3vxRqEcRheAWfledrdA
# 78  ChIJrZ8OGuRRqEcRLGuMfehHnk0
# 79  ChIJT9z_vvxRqEcRQvYDaqBLNS0
# 73  ChIJD3C43txRqEcRosYHlSG8PSM
# 65  ChIJNX291dxRqEcRUIJ_TyFnZL0
# 45  ChIJ1wLfeL5aqEcRlAtXMWA8gfE
# 75  ChIJ6wFH3MVRqEcRgOTx5SIY3Ys
# 86  ChIJyRESH_tRqEcRcTrX03kcwG8
# 54  ChIJ9_l59HBRqEcRlX-HAmUP6ps
# 31  ChIJl8laNkNOqEcR_cP9hIHMPlE
# 26  ChIJDxwnUmBPqEcR1mxWAXmC1zg
# 62  ChIJJzE_OMVRqEcRj2kHQw7R2FA
# 13  ChIJCal7aqZQqEcRS-dBiQO5RpY
# 93  ChIJ4-fNA_1RqEcRCO8DFPl778A
# 66  ChIJP5g9KttRqEcRFKxx7VlSTNA
# 21  ChIJWwxJ0vBOqEcRj0SpaaXimjg
# 49  ChIJN3sjK3BIqEcR3XYQNS3mgFQ
# 33  ChIJNZ52e-hQqEcRhTkVAtxjL6w
#
#                                              geometry  \
# 57  {'location': {'lat': 52.5038995, 'lng': 13.316...
# 36  {'location': {'lat': 52.50693949999999, 'lng':...
# 88  {'location': {'lat': 52.532864, 'lng': 13.4086...
# 78  {'location': {'lat': 52.5278283, 'lng': 13.400...
# 79  {'location': {'lat': 52.5332028, 'lng': 13.406...
# 73  {'location': {'lat': 52.51981, 'lng': 13.39222...
# 65  {'location': {'lat': 52.5201506, 'lng': 13.391...
# 45  {'location': {'lat': 52.4467753, 'lng': 13.343...
# 75  {'location': {'lat': 52.5148883, 'lng': 13.381...
# 86  {'location': {'lat': 52.5339432, 'lng': 13.401...
# 54  {'location': {'lat': 52.5003888, 'lng': 13.336...
# 31  {'location': {'lat': 52.5123147, 'lng': 13.448...
# 26  {'location': {'lat': 52.4884947, 'lng': 13.461...
# 62  {'location': {'lat': 52.5138203, 'lng': 13.386...
# 13  {'location': {'lat': 52.4748257, 'lng': 13.278...
# 93  {'location': {'lat': 52.5339085, 'lng': 13.409...
# 66  {'location': {'lat': 52.5151203, 'lng': 13.388...
# 21  {'location': {'lat': 52.5051816, 'lng': 13.469...
# 49  {'location': {'lat': 52.4470855, 'lng': 13.575...
# 33  {'location': {'lat': 52.499467, 'lng': 13.3067...
#
#                                     formatted_address  price_level  rating  \
# 57           Schlüterstraße 30, 10629 Berlin, Germany          2.0     4.6
# 36               Kantstraße 63, 10627 Berlin, Germany          2.0     4.2
# 88            Templiner Str. 7, 10119 Berlin, Germany          2.0     4.3
# 78            Auguststraße 49A, 10119 Berlin, Germany          NaN     4.0
# 79            Choriner Str. 72, 10119 Berlin, Germany          2.0     4.5
# 73        Universitätsstraße 2, 10117 Berlin, Germany          2.0     4.1
# 65           Georgenstraße 192, 10117 Berlin, Germany          2.0     4.3
# 45             Albrechtstr. 69, 12167 Berlin, Germany          1.0     3.9
# 75            Wilhelmstraße 75, 10117 Berlin, Germany          2.0     3.9
# 86        Fehrbelliner Str. 54, 10119 Berlin, Germany          NaN     4.6
# 54          Nürnberger Str. 28, 10789 Berlin, Germany          1.0     4.7
# 31             Gubener Str. 48, 10243 Berlin, Germany          2.0     4.7
# 26           Moosdorfstraße 14, 12435 Berlin, Germany          NaN     4.3
# 62              Jägerstraße 70, 10117 Berlin, Germany          2.0     4.6
# 13                 Clayallee 1, 14195 Dahlem, Germany          3.0     4.1
# 93           Schwedter Str. 13, 10119 Berlin, Germany          2.0     4.0
# 66     Friedrichstraße 167-168, 10117 Berlin, Germany          4.0     4.2
# 21       Neue Bahnhofstraße 32, 10245 Berlin, Germany          2.0     4.4
# 49              Alt-Köpenick 6, 12555 Berlin, Germany          2.0     4.3
# 33  Kurfürstendamm, Brandenburgische Str. 35, 1070...          2.0     4.6
#
#     user_ratings_total                                              types  \
# 57               386.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 36               515.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 88              2527.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 78               147.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 79               232.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 73               714.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 65              1350.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 45               718.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 75               872.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 86               163.0  ['store', 'restaurant', 'food', 'point_of_inte...
# 54               855.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 31              2098.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 26                 9.0  ['restaurant', 'bar', 'food', 'point_of_intere...
# 62               601.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 13               341.0  ['restaurant', 'cafe', 'food', 'point_of_inter...
# 93               421.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 66               957.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 21               387.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 49              1968.0  ['restaurant', 'food', 'point_of_interest', 'e...
# 33               940.0  ['restaurant', 'food', 'point_of_interest', 'e...
#
#                                     editorial_summary  ...  \
# 57  {'language': 'en', 'overview': 'Convivial bar/...  ...
# 36  {'language': 'en', 'overview': 'Nautically the...  ...
# 88  {'language': 'en', 'overview': 'Industrial-chi...  ...
# 78                                                NaN  ...
# 79                                                NaN  ...
# 73  {'language': 'en', 'overview': 'Refined Medite...  ...
# 65  {'language': 'en', 'overview': 'Antipasti, pas...  ...
# 45                                                NaN  ...
# 75  {'language': 'en', 'overview': 'Long-standing,...  ...
# 86                                                NaN  ...
# 54  {'language': 'en', 'overview': 'Down-to-earth ...  ...
# 31  {'language': 'en', 'overview': 'Pasta, pizza &...  ...
# 26                                                NaN  ...
# 62  {'language': 'en', 'overview': 'Daily specials...  ...
# 13                                                NaN  ...
# 93  {'language': 'en', 'overview': 'Pasta, gnocchi...  ...
# 66  {'language': 'en', 'overview': 'Italian restau...  ...
# 21  {'language': 'en', 'overview': 'Relaxed, art-f...  ...
# 49  {'language': 'en', 'overview': 'Lively canalsi...  ...
# 33  {'language': 'en', 'overview': 'Italian classi...  ...
#
#    wheelchair_accessible_entrance  \
# 57                            1.0
# 36                            NaN
# 88                            0.0
# 78                            NaN
# 79                            0.0
# 73                            1.0
# 65                            1.0
# 45                            NaN
# 75                            1.0
# 86                            NaN
# 54                            NaN
# 31                            NaN
# 26                            NaN
# 62                            0.0
# 13                            1.0
# 93                            NaN
# 66                            1.0
# 21                            NaN
# 49                            1.0
# 33                            NaN
#
#                                               website  \
# 57                         http://www.cali-bocca.com/
# 36                                                NaN
# 88                     http://www.standard-berlin.de/
# 78                             http://www.dapiada.de/
# 79                      https://vinoelibri.eatbu.com/
# 73                          https://www.vianova2.com/
# 65                  http://www.davinci-ristorante.de/
# 45                    http://www.restaurant-tiamo.de/
# 75                    http://www.ristorante-viale.de/
# 86                                                NaN
# 54                     http://ristorante-salepepe.de/
# 31                 http://www.portofino-trattoria.de/
# 26                                                NaN
# 62                         http://www.dolcini.berlin/
# 13                                                NaN
# 93                      http://donath-restaurant.com/
# 66                       https://www.boccadibacco.de/
# 21                     http://auszeit-am-ostkreuz.de/
# 49  https://www.facebook.com/Asteria-1382727202014...
# 33                              https://belluccis.de/
#
#     international_phone_number  \
# 57             +49 30 72023301
# 36              +49 30 3236053
# 88             +49 30 48625614
# 78             +49 30 54481948
# 79             +49 30 44058471
# 73             +49 30 20214861
# 65             +49 30 20143143
# 45             +49 30 79746300
# 75              +49 30 2297405
# 86             +49 30 53604815
# 54             +49 30 26107390
# 31             +49 30 23910610
# 26                         NaN
# 62             +49 30 24630456
# 13             +49 30 53157176
# 93             +49 30 28673611
# 66             +49 30 20672828
# 21             +49 30 24645139
# 49             +49 30 65496489
# 33             +49 30 28032233
#
#                                                photos  \
# 57  [{'height': 2563, 'html_attributions': ['<a hr...
# 36  [{'height': 3024, 'html_attributions': ['<a hr...
# 88  [{'height': 1462, 'html_attributions': ['<a hr...
# 78  [{'height': 1936, 'html_attributions': ['<a hr...
# 79  [{'height': 4032, 'html_attributions': ['<a hr...
# 73  [{'height': 1000, 'html_attributions': ['<a hr...
# 65  [{'height': 2250, 'html_attributions': ['<a hr...
# 45  [{'height': 2160, 'html_attributions': ['<a hr...
# 75  [{'height': 3024, 'html_attributions': ['<a hr...
# 86  [{'height': 4032, 'html_attributions': ['<a hr...
# 54  [{'height': 3024, 'html_attributions': ['<a hr...
# 31  [{'height': 4032, 'html_attributions': ['<a hr...
# 26  [{'height': 4032, 'html_attributions': ['<a hr...
# 62  [{'height': 4032, 'html_attributions': ['<a hr...
# 13  [{'height': 3744, 'html_attributions': ['<a hr...
# 93  [{'height': 3024, 'html_attributions': ['<a hr...
# 66  [{'height': 814, 'html_attributions': ['<a hre...
# 21  [{'height': 864, 'html_attributions': ['<a hre...
# 49  [{'height': 3456, 'html_attributions': ['<a hr...
# 33  [{'height': 4032, 'html_attributions': ['<a hr...
#
#                                             vicinity  \
# 57                         Schlüterstraße 30, Berlin
# 36                             Kantstraße 63, Berlin
# 88                          Templiner Str. 7, Berlin
# 78                          Auguststraße 49A, Berlin
# 79                          Choriner Str. 72, Berlin
# 73                      Universitätsstraße 2, Berlin
# 65                         Georgenstraße 192, Berlin
# 45                           Albrechtstr. 69, Berlin
# 75                          Wilhelmstraße 75, Berlin
# 86                      Fehrbelliner Str. 54, Berlin
# 54                        Nürnberger Str. 28, Berlin
# 31                           Gubener Str. 48, Berlin
# 26                         Moosdorfstraße 14, Berlin
# 62                            Jägerstraße 70, Berlin
# 13                               Clayallee 1, Dahlem
# 93                         Schwedter Str. 13, Berlin
# 66                   Friedrichstraße 167-168, Berlin
# 21                     Neue Bahnhofstraße 32, Berlin
# 49                            Alt-Köpenick 6, Berlin
# 33  Kurfürstendamm, Brandenburgische Str. 35, Berlin
#
#                                                   url  business_status  \
# 57  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 36  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 88  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 78  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 79  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 73  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 65  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 45  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 75  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 86  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 54  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 31  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 26  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 62  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 13  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 93  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 66  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 21  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 49  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
# 33  https://www.google.com/maps/place/?q=place_id:...      OPERATIONAL
#
#     permanently_closed                                          plus_code  \
# 57                 NaN  {'compound_code': 'G838+HQ Berlin', 'global_co...
# 36                 NaN  {'compound_code': 'G843+QM Berlin', 'global_co...
# 88                 NaN  {'compound_code': 'GCM5+4F Berlin', 'global_co...
# 78                 NaN  {'compound_code': 'GCH2+49 Berlin', 'global_co...
# 79                 NaN  {'compound_code': 'GCM4+7P Berlin', 'global_co...
# 73                 NaN  {'compound_code': 'G99R+WV Berlin', 'global_co...
# 65                 NaN  {'compound_code': 'G9CR+3G Berlin', 'global_co...
# 45                 NaN  {'compound_code': 'C8WV+P7 Berlin', 'global_co...
# 75                 NaN  {'compound_code': 'G97J+XF Berlin', 'global_co...
# 86                 NaN  {'compound_code': 'GCM2+HQ Berlin', 'global_co...
# 54                 NaN  {'compound_code': 'G82P+5C Berlin', 'global_co...
# 31                 NaN  {'compound_code': 'GC6X+W9 Berlin', 'global_co...
# 26                 NaN  {'compound_code': 'FFQ6+9M Berlin', 'global_co...
# 62                 NaN  {'compound_code': 'G97P+GP Berlin', 'global_co...
# 13                 NaN  {'compound_code': 'F7FH+W7 Berlin', 'global_co...
# 93                 NaN  {'compound_code': 'GCM5+HV Berlin', 'global_co...
# 66                 NaN  {'compound_code': 'G98Q+2H Berlin', 'global_co...
# 21                 NaN  {'compound_code': 'GF49+4J Berlin', 'global_co...
# 49                 NaN  {'compound_code': 'CHWG+R4 Berlin', 'global_co...
# 33                 NaN  {'compound_code': 'F8X4+QP Berlin', 'global_co...
#
#                                           model_input
# 57  'pasta was great although pizza was not extrao...
# 36  'ordered pizza marinara and inferno, along wit...
# 88  'standard serious pizza had been on our to do ...
# 78  'a little family restaurant, cosy vibe. best c...
# 79  'amazing pizza and pasta! one of the best pizz...
# 73  'this restaurant is unfortunately only fake it...
# 65  'one of the best place for original italian pi...
# 45  '- very friendly and helpful staff- made me an...
# 75  'very good place for italian food! pizza and p...
# 86  'really good food for a reasonable price, we t...
# 54  'really nice cosy italian restaurant. the food...
# 31  'good food with a very wonderful atmosphere. i...
# 26  'friendly and courteous service, restaurant we...
# 62  'like most of the reviews on here, cannot faul...
# 13  'good food service was great busy place', 'thi...
# 93  "we had the most wonderful meal at donath last...
# 66  'popped in for a late lunch and very much enjo...
# 21  'great ambience and wonderful service! very fr...
# 49  'good food, friendly staff, pretty big portion...
# 33  "it was an ok experience. the food we have ord...
#
# [20 rows x 33 columns]

# %% [markdown]
# # code snippets

# %%
import pickle

#Load sentences & embeddings from disc
with open('embeddings.pkl', "rb") as fIn:
    stored_data = pickle.load(fIn)
    stored_sentences = stored_data['sentences']
    stored_embeddings = stored_data['embeddings']

# %%
# Load the model from .joblib file
import joblib
with open("NearestNeighbors_clf.joblib", "rb") as file:
    loaded_model = joblib.load(file)

# %%
# Out:
# array(['\'authentic german cuisine, friendly & fast served. huge portion, tasted like delicious home-cooked meal. highly recommended for salty food lovers. however cash only, which is also quite german.\', \'very tasty german food. worth a visit.\', \'great atmosphere with old s-bahn decorations. great space at the table and between tables. staff really nice and helpful, knowledgeable and advising for a good meal. good choice of dishes and good size of food, quality is good but could be better. price very reasonable, will go again. parking available inside.\', \'really amazing place, finger licking food and generous hospitality! really a hidden gem i never expected to find! their grill teller is really nice with 2 types of sauces. i loved the green pepper sauce in particular! it was soooo good! many families come here with kids and their kids menu is also good! the fish fingers with mash potatos and peas looked and tasted so good!\', "went here for a birthday and wasn\'t sure what to expect! service was great, food was delicious, prices were excellent! i was very full and happy",  \'Pork knuckles, schnitzel & goulash at an 1890s tavern filled with train memorabilia, plus a garden.\', \'types\': [\'restaurant\', \'food\', \'establishment\']',
#        '\'this must be one of the best kept culinary secrets in berlin. central in city west, but discreetly tucked away, it can rival all those michelin stars out there. we visite for the berliner morgenpost dinner menu and were flabbergasted by the creativity, presentation and savour of each individual course - accompanied by thoughtfully selected wines. the service was impeccable, knowledgable and exceptionally friendly (gina). we have already booked for two events, and will be back for lunch next time we are diowntown.\', "i\'m not sure how this restaurant has almost 5 stars... we ate here for lunch and were one of maybe 3 tables and the service was awful. we had to be on top of our servers for everything - water, main course, dessert, coffee and our check. it\'s frustrating when the restaurant is empty and the waiter blatantly forgets to bring out your main. our food only came out right after we asked where it was lol... as for the food it was ok. app wasn\'t great, main was good but not michelin level great.", \'unfortunately, neither the taste nor the service matches the presentation of the dish. seems like they are lost in between average restaurants and michelin star worthy ones. the menu is overly random, most dishes lack seasoning and any taste.\', \'went there for lunch this afternoon after reading various review , absolutely fabulous. from food quality , service and price point of view this restaurant is definitely our best found in berlin so far.\', \'i am sorry to write you about a miserable customer service experience with the hotel am steinplatz in berlin, an autograph collection bonvoy hotel. the service has been horrible. the real matter started with the restaurant putting cilantro/coriander in multiple dishes on the menu. while this allergy is not like peanuts or shrimp many people do have an allergy including myself . the restaurant neither indicated on the menu that coriander was used in the dishes i ordered but the service staff did not ask either. and the restaurant not only did not inform or ask about allergens but blamed me for not informing the restaurant. the waitstaff has the audacity to say in germany it is expected the customer informs the restaurant. i can assure you that is not the case. and the customer should be right. so much for any positive reviews. i advise everyone who has taste (or any food allergies) to avoid the restaurant am steinplatz like the plague!\',  \'Sophisticated restaurant with a garden & courtyard offering a range of seasonal & regional dishes.\', \'types\': [\'restaurant\', \'food\', \'establishment\']',
#        '\'lovely authentic germany restaurant in a beautiful setting. the food was hearty and delicious, very quick service and tasted fresh. our waiter was incredible, very attentive and accommodating. lively atmosphere when we were there with most tables full. would recommend for a good hearty german meal.\', \'nice german restaurant just below the friedrichst. train station. service was prompt, food tasted fresh & homely. the price is very reasonable too!\', "this \'salmon fillet fried\' dish was such a delight. one of the best, non-spicy dishes i\'ve ever had in my life. such a refined taste. the interior of the restaurant was beautiful too!", \'decent food and very reasonable price. services were very slow and we were served the wrong dish at first.\', \'superb location and atmosphere, very pleasant and professional service. the dishes were generous and tasty, priced reasonably well. recommended.\',  \'Homestyle dishes at a bistro with an old-world vibe, an arched ceiling & a shady courtyard.\', \'types\': [\'restaurant\', \'food\', \'establishment\']',
#        ...,
#        '\'food taste is good for indian visitor\', \'good\', "we ended up here for a cocktail and didn\'t regret it. very friendly staff, fast service and delicious cocktails", "very nice waitress when i arrived in the bar but completely different when paying. i had to pay eur8 for consumption, i only had eur7.87 in cash and she didn\'t want to accept the card below eur10, so she pushed me to consume more. fortunately a customer gave me the missing few cents but the waitress was not at all okay with the situation", \'a good place. excellent service, very nice staff. the interior is also pleasing to the eye. as are the prices. there are tables outside as well. it is convenient that it is within walking distance from the bus station. if someone has just arrived or is waiting for a transplant - a good place to drink coffee and spend time here. the coffee is delicious.\'',
#        '"delicious food, kind service, a must stop for a good meal! i had the calzone with ham, salami, and mushrooms, couldn\'t stop eating! the decor is lively and cute as well.", \'the staff is italian. food is awesome. friendly true italian service.\', \'the food was ok but nothing special about it.. it is a nice place to go and enjoy a simple meal. the restaurant itself is small and the stuff friendly.\', \'very good pizza. my wife commented that her pasta was a little too al dente, but the dish otherwise tasted lovely. friendly staff and very nice wine, albeit a little more expensive than other local establishments. overall a lovely atmosphere and good food. recommended.\', \'great place. very intimate and cozy. its one of our most beloved restaurants around. the food is fresh and cooked magnificently by vittorio, a very cool italian. prices are quite modest for the quality of food and drinks. in fact, we have been here several times and its ranking has just gone higher. i wanted to take a pic of my dish but i already ate it. special mention to rosita, who makes this place feel like home.\'',
#        '\'our favourite indian cafe in berlin! always so friendly atmosphere and very very delicious food! thank you so much! we are your fans\', \'food is delicious! specially daal makhni is just so authentic and mouth watering. do try if you like indian cuisine.\', \'interesting place - i wanted to try it since i live nearby. the entrance is located right next to the actual tennis court (you can go through the lockers as well but there is an official entrance). we were the only two people at that time, service was great and fast. place itself is actually nice, not as "indianized" as other places were everything is golden and what not. we ordered spinach cheese and mango chicken - both was tasty and well done. the batura could have been better, but the mango lassi was great. overall it seems a nice place (a bit of a hidden gem) and really well taken care of. will visit again!\', "if you happen to be nearby and hungry, make sure to visit this place. from its location, the way it looks, and the name suggesting two cuisine in one, it may not sound that fancy at first, but - you\'ll get a delicious indian food (haven\'t tried italian options yet) - which will be served by a polite and friendly staff - for which you\'ll pay a very affordable price (there are also lunch-offers, which are updated weekly) - and if you\'re lucky, you\'ll get to watch people play tennis in real-life resolution :) with all that, this place is a true hidden gem.", \'super friendly staff and nice butter chicken, will definitely come back!\',  \'Mellow restaurant dishing up traditional Indian specialties, plus Italian snacks such as pizza.\', \'types\': [\'restaurant\', \'food\', \'establishment\']'],
#       dtype=object)
